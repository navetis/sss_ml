# %%
import glob
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
palette = {'all_kfold': 'tab:blue', 'ts': 'tab:orange', 'all_nested': 'tab:green', 'fs_nested_pt_kfold': 'tab:red', 'fs_kfold_pt_nested': 'tab:purple'}

# %%
path = os.getcwd()
data_files = glob.glob(os.path.join(path, "binary_subgroups/binary*"))

li = []
for filename in data_files:
    df = pd.read_csv(filename)
    li.append(df)


subgroup_df = pd.concat(li, axis=0, ignore_index=True)

new_names = dict([(i,'metric_'+ i) for i in subgroup_df.iloc[0:1,10:].columns.values])
subgroup_df.rename(columns=new_names, inplace=True)


subgroup_df = subgroup_df[subgroup_df['metric_accuracy'].notna()]
subgroup_df
# Out:
#        subgroup                model main_metric  sample_size  \
# 0         young  logistic_regression    accuracy         0.03
# 1         young  logistic_regression    accuracy         0.03
# 2         young  logistic_regression    accuracy         0.03
# 3         young  logistic_regression    accuracy         0.03
# 4         young  logistic_regression    accuracy         0.03
# ...         ...                  ...         ...          ...
# 383341    elder                  svm    accuracy         1.00
# 383342    elder                  svm    accuracy         1.00
# 383343    elder                  svm    accuracy         1.00
# 383344    elder                  svm    accuracy         1.00
# 383345    elder                  svm    accuracy         1.00
#
#        feature_selector  feature_selection_frac     validation_type  \
# 0                   rfe                     0.4                  ts
# 1                   rfe                     0.4                  ts
# 2                   rfe                     0.4                  ts
# 3                   rfe                     0.4                  ts
# 4                   rfe                     0.4                  ts
# ...                 ...                     ...                 ...
# 383341              rfe                     1.0  fs_kfold_pt_nested
# 383342              rfe                     1.0  fs_kfold_pt_nested
# 383343              rfe                     1.0  fs_kfold_pt_nested
# 383344              rfe                     1.0  fs_kfold_pt_nested
# 383345              rfe                     1.0  fs_kfold_pt_nested
#
#         train_size  cv_split_size  par_split_size  metric_accuracy  \
# 0              0.6            NaN               2         0.250000
# 1              0.6            NaN               2         0.250000
# 2              0.6            NaN               2         0.250000
# 3              0.6            NaN               2         0.250000
# 4              0.6            NaN               2         0.750000
# ...            ...            ...             ...              ...
# 383341         NaN           13.0              13         0.699176
# 383342         NaN           13.0              13         0.699176
# 383343         NaN           13.0              13         0.699176
# 383344         NaN           13.0              13         0.699176
# 383345         NaN           13.0              13         0.699176
#
#         metric_balanced_accuracy  metric_f1  metric_precision  metric_recall
# 0                       0.250000   0.200000          0.166667       0.250000
# 1                       0.166667   0.300000          0.375000       0.250000
# 2                       0.250000   0.200000          0.166667       0.250000
# 3                       0.500000   0.100000          0.062500       0.250000
# 4                       0.750000   0.733333          0.833333       0.750000
# ...                          ...        ...               ...            ...
# 383341                  0.500000   0.576853          0.492371       0.699176
# 383342                  0.500000   0.576853          0.492371       0.699176
# 383343                  0.500000   0.576853          0.492371       0.699176
# 383344                  0.500000   0.576853          0.492371       0.699176
# 383345                  0.500000   0.576853          0.492371       0.699176
#
# [380400 rows x 15 columns]

# %%
selection = subgroup_df[
    (subgroup_df['feature_selection_frac'] == 0.7)
    & (subgroup_df['par_split_size'] == 13.0)
    & (subgroup_df['main_metric'] == 'accuracy')
    & ((subgroup_df['train_size'] == 0.8) | subgroup_df['train_size'].isna())
    & ((subgroup_df['cv_split_size'] == 13.0) | subgroup_df['cv_split_size'].isna())]

# %%
selection = selection.reset_index()

# %%
pivoted_subgroup = pd.wide_to_long(selection, stubnames='metric', i='index', j='metric_type', sep='_', suffix=r'\w+')
pivoted_subgroup.reset_index(inplace=True)
pivoted_subgroup = pivoted_subgroup.drop('index', axis=1)
pivoted_subgroup.rename(columns={'metric': 'metric_measurement'}, inplace=True)
pivoted_subgroup
# Out:
#       metric_type subgroup  par_split_size  sample_size     validation_type  \
# 0        accuracy    young              13          0.1                  ts
# 1        accuracy    young              13          0.1                  ts
# 2        accuracy    young              13          0.1                  ts
# 3        accuracy    young              13          0.1                  ts
# 4        accuracy    young              13          0.1                  ts
# ...           ...      ...             ...          ...                 ...
# 29495      recall    elder              13          1.0  fs_kfold_pt_nested
# 29496      recall    elder              13          1.0  fs_kfold_pt_nested
# 29497      recall    elder              13          1.0  fs_kfold_pt_nested
# 29498      recall    elder              13          1.0  fs_kfold_pt_nested
# 29499      recall    elder              13          1.0  fs_kfold_pt_nested
#
#       main_metric                model  train_size feature_selector  \
# 0        accuracy  logistic_regression         0.8              rfe
# 1        accuracy  logistic_regression         0.8              rfe
# 2        accuracy  logistic_regression         0.8              rfe
# 3        accuracy  logistic_regression         0.8              rfe
# 4        accuracy  logistic_regression         0.8              rfe
# ...           ...                  ...         ...              ...
# 29495    accuracy                  svm         NaN              rfe
# 29496    accuracy                  svm         NaN              rfe
# 29497    accuracy                  svm         NaN              rfe
# 29498    accuracy                  svm         NaN              rfe
# 29499    accuracy                  svm         NaN              rfe
#
#        cv_split_size  feature_selection_frac  metric_measurement
# 0                NaN                     0.7            0.666667
# 1                NaN                     0.7            1.000000
# 2                NaN                     0.7            0.666667
# 3                NaN                     0.7            1.000000
# 4                NaN                     0.7            1.000000
# ...              ...                     ...                 ...
# 29495           13.0                     0.7            0.776099
# 29496           13.0                     0.7            0.796703
# 29497           13.0                     0.7            0.787088
# 29498           13.0                     0.7            0.806319
# 29499           13.0                     0.7            0.795330
#
# [29500 rows x 12 columns]

# %%
gf = pivoted_subgroup['subgroup'].replace({'young': 291, 'middle': 524, 'elder': 103})
r = pivoted_subgroup['sample_size'] * gf
pivoted_subgroup['sample_size'] = r
pivoted_subgroup
# Out:
#       metric_type subgroup  par_split_size  sample_size     validation_type  \
# 0        accuracy    young              13         29.1                  ts
# 1        accuracy    young              13         29.1                  ts
# 2        accuracy    young              13         29.1                  ts
# 3        accuracy    young              13         29.1                  ts
# 4        accuracy    young              13         29.1                  ts
# ...           ...      ...             ...          ...                 ...
# 29495      recall    elder              13        103.0  fs_kfold_pt_nested
# 29496      recall    elder              13        103.0  fs_kfold_pt_nested
# 29497      recall    elder              13        103.0  fs_kfold_pt_nested
# 29498      recall    elder              13        103.0  fs_kfold_pt_nested
# 29499      recall    elder              13        103.0  fs_kfold_pt_nested
#
#       main_metric                model  train_size feature_selector  \
# 0        accuracy  logistic_regression         0.8              rfe
# 1        accuracy  logistic_regression         0.8              rfe
# 2        accuracy  logistic_regression         0.8              rfe
# 3        accuracy  logistic_regression         0.8              rfe
# 4        accuracy  logistic_regression         0.8              rfe
# ...           ...                  ...         ...              ...
# 29495    accuracy                  svm         NaN              rfe
# 29496    accuracy                  svm         NaN              rfe
# 29497    accuracy                  svm         NaN              rfe
# 29498    accuracy                  svm         NaN              rfe
# 29499    accuracy                  svm         NaN              rfe
#
#        cv_split_size  feature_selection_frac  metric_measurement
# 0                NaN                     0.7            0.666667
# 1                NaN                     0.7            1.000000
# 2                NaN                     0.7            0.666667
# 3                NaN                     0.7            1.000000
# 4                NaN                     0.7            1.000000
# ...              ...                     ...                 ...
# 29495           13.0                     0.7            0.776099
# 29496           13.0                     0.7            0.796703
# 29497           13.0                     0.7            0.787088
# 29498           13.0                     0.7            0.806319
# 29499           13.0                     0.7            0.795330
#
# [29500 rows x 12 columns]

# %%
accuracy_subgroups = pivoted_subgroup[pivoted_subgroup['metric_type'] == 'accuracy']
accuracy_subgroups_reduced = accuracy_subgroups[(accuracy_subgroups['validation_type'] == 'ts') | (accuracy_subgroups['validation_type'] == 'all_nested') | (accuracy_subgroups['validation_type'] == 'all_kfold')]

# %%
plt.rcParams.update({'font.size': 15})
sns.relplot(x='sample_size', data=accuracy_subgroups_reduced, hue='validation_type', kind='line', y='metric_measurement',  ci=95, row='model', col='subgroup', palette=palette, style='validation_type', markers=True, dashes=False)
plt.show()
